# %%
import pandas as pd
import geopandas as gpd
import requests
import lxml.html as lh
from bs4 import BeautifulSoup
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
texas = gpd.read_file("County.shp")
texas.head()
# Out:
#    FID TXDOT_CNTY  GID  SHAPE_Leng  \
# 0    1     County   38    0.537083
# 1    2     County   39    0.078216
# 2    3     County   40    0.242348
# 3    4     County   41    0.333182
# 4    5     County   43    0.020484
#
#                                             geometry
# 0  LINESTRING (-99.45372792299997 27.265074564000...
# 1  LINESTRING (-98.52233769499998 27.343284604000...
# 2  LINESTRING (-98.95454780099999 27.269424577000...
# 3  LINESTRING (-98.79845776899998 27.353864600000...
# 4  LINESTRING (-97.84493754199997 27.567274672000...

# %%
texas.plot(figsize=(10,10))
