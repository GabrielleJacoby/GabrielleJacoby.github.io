# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
texas = gpd.read_file("tl_2016_48_cousub.shp")

# %%
type(texas)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
texas
# Out:
#     STATEFP COUNTYFP COUSUBFP  COUSUBNS       GEOID                 NAME  \
# 0        48      423    93950  01939272  4842393950            Troup-Arp
# 1        48      423    94205  01939323  4842394205           Whitehouse
# 2        48      423    93970  01939276  4842393970                Tyler
# 3        48      423    94260  01939334  4842394260               Winona
# 4        48      039    90094  01938494  4803990094             Angleton
# 5        48      039    90055  01938486  4803990055       Alvin-Pearland
# 6        48      039    90415  01938558  4803990415           Brazosport
# 7        48      253    91695  01938820  4825391695               Hamlin
# 8        48      465    90995  01938677  4846590995              Del Rio
# 9        48      465    91000  01938678  4846591000    Del Rio Northeast
# 10       48      465    91005  01938679  4846591005    Del Rio Northwest
# 11       48      253    93720  01939226  4825393720             Stamford
# ...

# %%
texas.plot(cmap='jet', column="COUNTYFP", figsize=(10,10))
